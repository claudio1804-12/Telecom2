# %% [markdown]
# <a href="https://colab.research.google.com/github/claudio1804-12/Telecom2/blob/main/Telecom2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/claudio1804-12/Telecom2/refs/heads/main/df_norm.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df=df.drop('customerID', axis=1)

# %%
df_corr = df[['Charges.Total','tenure','Charges.Monthly','SeniorCitizen']]
df_corr.corr()
# Out:
#                  Charges.Total    tenure  Charges.Monthly  SeniorCitizen
# Charges.Total         1.000000  0.826178         0.651174       0.103006
# tenure                0.826178  1.000000         0.247900       0.016567
# Charges.Monthly       0.651174  0.247900         1.000000       0.220173
# SeniorCitizen         0.103006  0.016567         0.220173       1.000000

# %%
df = df.drop(['tenure','Charges.Monthly'], axis=1)
df.head()
# Out:
#   Churn  gender  SeniorCitizen Partner Dependents PhoneService MultipleLines  \
# 0    No  Female              0     Yes        Yes          Yes            No
# 1    No    Male              0      No         No          Yes           Yes
# 2   Yes    Male              0      No         No          Yes            No
# 3   Yes    Male              1     Yes         No          Yes            No
# 4   Yes  Female              1     Yes         No          Yes            No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
# 3     Fiber optic             No          Yes              Yes          No
# 4     Fiber optic             No           No               No         Yes
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
df_encode = OneHotEncoder(sparse=False)
df_encode = encoder.fit_transform(df[["Churn_no","Contrato"]])
# Out:
#    SeniorCitizen  Charges.Total  Churn_No  Churn_Yes  gender_Female  \
# 0              0         593.30      True      False           True
# 1              0         542.40      True      False          False
# 2              0         280.85     False       True          False
# 3              1        1237.85     False       True          False
# 4              1         267.40     False       True           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True          False            True  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True       False         True           True           False  ...
# 4        False       False         True           True           False  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# ...
